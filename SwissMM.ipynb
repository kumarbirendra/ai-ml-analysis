# %% [markdown]
# <a href="https://colab.research.google.com/github/kumarbirendra/ai-ml-analysis/blob/master/SwissMM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
from urllib.request import Request,urlopen
from bs4 import BeautifulSoup
# %matplotlib inline

# %%
all_smm_merchant_list = []
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL1709")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4784")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4797")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4787")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4794")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL1424")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL3219")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL3836")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4638")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL1425")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4790")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4310")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4783")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4804")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4796")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4806")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4796")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4804")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4783")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4798")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4795")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4802")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4785")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4793")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL894")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4800")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL2592")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL1422")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL2749")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4629")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL945")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL2596")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4546")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL2892")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL2634")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4788")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL2659")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4786")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL2576")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4223")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4204")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4799")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4789")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4183")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL2478")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL2524")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL2461")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4669")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL391")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4810")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL2528")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL2741")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4738")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL2591")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4792")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4243")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL2594")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL759")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4555")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4059")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4163")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4514")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4332")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL264")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL2955")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL193")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL2451")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4498")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4217")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL2537")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL32")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4817")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4628")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4812")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL2345")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL3616")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL3999")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL2900")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL366")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL3619")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL967")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4816")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4818")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL1474")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL3823")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL372")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL2884")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4053")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4080")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4827")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4314")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4833")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4127")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL251")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL3891")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4825")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4820")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4528")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4527")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4822")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4829")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4826")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4823")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4819")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4821")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4824")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4831")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4832")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4830")
all_smm_merchant_list.append("https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4828")
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36','Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
session = requests.Session()
merchant_link_working =0
merchant_link_not_working = 0
for smm_merchant in all_smm_merchant_list:
  #print(smm_merchant)
  r = session.get(smm_merchant,headers=headers)
  soup = BeautifulSoup(r.text, 'lxml')
  data = soup.text
  str_cells = str(data)
  clean = re.compile('<.*?>')
  clean_data = (re.sub(clean, '',str_cells))
  if(str(clean_data).find("Miles & More")>= 0):
    print("Merchant shop link is working :- " + smm_merchant)
    merchant_link_working = merchant_link_working + 1
  else:
    print("Merchant shop link is **not working :- " + smm_merchant)
    merchant_link_not_working = merchant_link_not_working + 1

print("=========================================================================================================")
print("=========================================================================================================")
print ("***************Total Swiss M&M Merchant Working      : " + str(merchant_link_working) +"      ****************")
print ("***************Total Swiss M&M Merchant *Not Working : " + str(merchant_link_not_working) +"        *****************")
# Out:
# Merchant shop link is working :- https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL1709
# Merchant shop link is working :- https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4784
# Merchant shop link is working :- https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4797
# Merchant shop link is working :- https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4787
# Merchant shop link is working :- https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4794
# Merchant shop link is working :- https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL1424
# Merchant shop link is working :- https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL3219
# Merchant shop link is working :- https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL3836
# Merchant shop link is working :- https://shopping.miles-and-more.com/rexmerchantpage?merchantCode=MAL4638
# ...
